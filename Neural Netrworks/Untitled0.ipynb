# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Model(nn.Module):                                                     # Create a model class that inherits nn.Module
  def __init__(self, in_features=4, H1=8, H2=89, out_features=3):           # Define input layer (4 features of Iris flower), Hidden layer1 (Neurons)
                                                                            # Hidden layer2 (Neurons), output layer (3 classes of Iris flower)
    super(Model, self).__init__()                                           # instantiate our nn.Module
    self.fc1 = nn.Linear(in_featues, H1)                                    # fc= Fully connect.
    self.fc2 = nn.Linear(H1, H2)                                            # fully connects one layer to all the nodes of next layer
    self.out = nn.Linear(H2, out_features)

  def forward(self, x):                                                     #
    x = F.relu(self, fc1(x))
    x = F.relu(self, fc2(x))
    x = self.out(x)
    return x

    torch.manual_seed(21)                                                   # Pick a manual seed for randomization
    model = Model ()                                                        # Create an instance of model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
url = 'https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv'
my_df = pd.read_csv(url)

# %%
my_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
my_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
my_df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
my_df ['vareity'] = my_df['vareity'].replace('setosa', 0)
 my_df ['vareity'] = my_df['vareity'].replace('virginica', 2)
 my_df ['vareity'] = my_df['vareity'].replace('versicolor', 1)
# Out:
#   File "<ipython-input-12-f18201337041>", line 2
#     my_df ['vareity'] = my_df['vareity'].replace('virginica', 2)
#     ^
# IndentationError: unexpected indent

# %%
# Changed last column from strings to int
my_df ['species'] = my_df['species'].replace('setosa', 0)
my_df ['species'] = my_df['species'].replace('versicolor', 1)
my_df ['species'] = my_df['species'].replace('virginica', 2)

# %%
my_df.Head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-98e00b819538> in <cell line: 1>()
# ----> 1 my_df.Head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Head'

# %%
my_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
my_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e89a4f906a9f> in <cell line: 1>()
# ----> 1 my_df
#
# NameError: name 'my_df' is not defined
